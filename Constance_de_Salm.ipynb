# %% [markdown]
# # Constance de Salm #
#
# Importing the needed libraries.

# %%
import pandas as pd
import re

# %% [markdown]
# Loading the Dataset via pandas.

# %%
df = pd.read_csv("Donnees_Lettres/20211116_Constance_de_Salm_Korrespondenz_Inventar_Briefe.csv", sep=';', encoding='utf8')
list(df)
# Out:
# ['FuD-Key',
#  'letzte Änderung',
#  'Dokumenttyp',
#  'URL',
#  'Nr.',
#  'Verfasser',
#  'GND (Verfasser)',
#  'VIAF (Verfasser)',
#  ' Empfänger',
#  'GND (Empfänger)',
#  'VIAF (Empfänger)',
#  'Datierung (JJJJ-MM-TT)',
#  'Alternative Datierung',
#  'Ausstellungsort',
#  'Geonames (Ausstellungsort)',
#  'Empfangsort',
#  'Geonames (Empfangsort)',
#  'Vorlage',
#  'Vollständigkeit des Archivals',
#  'Erläuterung Unvollständigkeit',
#  'Umfang in Seiten',
#  'Anfang des Briefes',
#  'Inhaltliche Stichpunkte',
#  'Weitere Personen',
#  'GND (Weitere Personen)',
#  'VIAF (Weitere Personen)',
#  'Orte',
#  'Geonames (Orte)',
#  'Schlagwörter',
#  'Editionen',
#  'Vermerk',
#  'Bestand',
#  'Verweise',
#  'Digitalisate: Dateiname (Signatur)',
#  'Zitierempfehlung']

# %%
df['Nr.']
# Out:
# 0         CdS/92/002-004
# 1             CdS/89/064
# 2        C10/S82/368-370
# 3            C02/S09/127
# 4           C03/S18a/124
#               ...
# 10720     CdS/31/039-040
# 10721     CdS/31/079-080
# 10722          CdS/31/21
# 10723     CdS/95/008-009
# 10724    C06/S43/415-416
# Name: Nr., Length: 10725, dtype: object

# %% [markdown]
# Extracting just the letters which were written by the same hand.

# %%
search = [r'CdS_16.*', r'CdS_17.*', r'CdS_26.*', r'CdS_27.*', r'CdS_28.*', r'CdS_29.*', r'CdS_30.*', r'CdS_31.*']
df_part = pd.DataFrame()
for i, v in df.iterrows():
    found = False
    for s in search:
        key = v['Nr.'].replace('/', '_')
        if re.search(s, key) is not None:
            found = True
            break
    if found:
        df_part = df_part.append(v)
df_part
# Out:
#            FuD-Key   letzte Änderung Dokumenttyp  \
# 2892   CdS-b1-08jg  26.08.2021 10:44       Brief
# 3378   CdS-b1-08je  26.08.2021 10:44       Brief
# 4327   CdS-b1-08jf  26.08.2021 10:44       Brief
# 5439   CdS-b1-07r3  26.08.2021 10:44       Brief
# 5467   CdS-b1-07vy  26.08.2021 10:44       Brief
# ...            ...               ...         ...
# 10718  CdS-b1-08jb  26.08.2021 10:44       Brief
# 10719  CdS-b1-08iz  26.08.2021 10:44       Brief
# 10720  CdS-b1-08in  26.08.2021 10:44       Brief
# 10721  CdS-b1-08j6  26.08.2021 10:44       Brief
# 10722  CdS-b1-08ib  26.08.2021 10:44       Brief
#
#                                                      URL             Nr.  \
# 2892   https://constance-de-salm.de/archiv/#/document...  CdS/31/166-167
# 3378   https://constance-de-salm.de/archiv/#/document...  CdS/31/132-135
# 4327   https://constance-de-salm.de/archiv/#/document...  CdS/31/158-160
# 5439   https://constance-de-salm.de/archiv/#/document...      CdS/28/003
# 5467   https://constance-de-salm.de/archiv/#/document...  CdS/16/003-004
# ...                                                  ...             ...
# 10718  https://constance-de-salm.de/archiv/#/document...  CdS/31/098-099
# 10719  https://constance-de-salm.de/archiv/#/document...  CdS/31/062-063
# 10720  https://constance-de-salm.de/archiv/#/document...  CdS/31/039-040
# 10721  https://constance-de-salm.de/archiv/#/document...  CdS/31/079-080
# 10722  https://constance-de-salm.de/archiv/#/document...       CdS/31/21
#
#                       Verfasser                 GND (Verfasser)  \
# 2892   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 3378   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 4327   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 5439   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 5467   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# ...                         ...                             ...
# 10718  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10719  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10720  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10721  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10722  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
#
#                    VIAF (Verfasser)  \
# 2892   https://viaf.org/viaf/121051
# 3378   https://viaf.org/viaf/121051
# 4327   https://viaf.org/viaf/121051
# 5439   https://viaf.org/viaf/121051
# 5467   https://viaf.org/viaf/121051
# ...                             ...
# 10718  https://viaf.org/viaf/121051
# 10719  https://viaf.org/viaf/121051
# 10720  https://viaf.org/viaf/121051
# 10721  https://viaf.org/viaf/121051
# 10722  https://viaf.org/viaf/121051
#
#                                                Empfänger  \
# 2892   Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 3378   Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 4327   Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 5439   Duval, Alexandre, eigentl. Alexandre-Vincent P...
# 5467   Théis, Alexandre Étienne Guillaume, baron de (...
# ...                                                  ...
# 10718  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10719  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10720  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10721  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10722  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
#
#                       GND (Empfänger)  ...  \
# 2892   http://d-nb.info/gnd/121286169  ...
# 3378   http://d-nb.info/gnd/121286169  ...
# 4327   http://d-nb.info/gnd/121286169  ...
# 5439   http://d-nb.info/gnd/104201088  ...
# 5467   http://d-nb.info/gnd/120564734  ...
# ...                               ...  ...
# 10718  http://d-nb.info/gnd/121286169  ...
# 10719  http://d-nb.info/gnd/121286169  ...
# 10720  http://d-nb.info/gnd/121286169  ...
# 10721  http://d-nb.info/gnd/121286169  ...
# 10722  http://d-nb.info/gnd/121286169  ...
#
#                                  VIAF (Weitere Personen)            Orte  \
# 2892                     https://viaf.org/viaf/188712285             NaN
# 3378   http://viaf.org/viaf/32148970; n/a; http://via...           Tours
# 4327         http://viaf.org/viaf/1847152636116120051820             NaN
# 5439                       http://viaf.org/viaf/59072566          Aachen
# 5467         http://viaf.org/viaf/1847152636116120051820             NaN
# ...                                                  ...             ...
# 10718                 http://viaf.org/viaf/54933372; n/a           Tours
# 10719          https://viaf.org/viaf/188712285; n/a; n/a             NaN
# 10720                                           n/a; n/a    Tours; Coucy
# 10721                                      n/a; n/a; n/a  Orléans; Coucy
# 10722                                                NaN             NaN
#
#                                          Geonames (Orte)  \
# 2892                                                 NaN
# 3378                    https://www.geonames.org/2972191
# 4327                                                 NaN
# 5439                    https://www.geonames.org/3247449
# 5467                                                 NaN
# ...                                                  ...
# 10718                   https://www.geonames.org/2972191
# 10719                                                NaN
# 10720  https://www.geonames.org/2972191; https://www....
# 10721  https://www.geonames.org/2989317; https://www....
# 10722                                                NaN
#
#                                             Schlagwörter Editionen  Vermerk  \
# 2892   CdS: Œuvres complètes (1842); Tod/Trauer; CdS:...       NaN      NaN
# 3378                Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 4327                Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 5439                           Deutschland - Wahrnehmung       NaN      NaN
# 5467                                          Verbrechen       NaN      NaN
# ...                                                  ...       ...      ...
# 10718                                    Prozess/Gericht       NaN      NaN
# 10719               Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 10720                                    Prozess/Gericht       NaN      NaN
# 10721               Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 10722                                    Prozess/Gericht       NaN      NaN
#
#             Bestand                                           Verweise  \
# 2892   Schloss Dyck                                                NaN
# 3378   Schloss Dyck                                                NaN
# 4327   Schloss Dyck                                                NaN
# 5439   Schloss Dyck  (https://constance-de-salm.de/archiv/#/documen...
# 5467   Schloss Dyck                                                NaN
# ...             ...                                                ...
# 10718  Schloss Dyck                                                NaN
# 10719  Schloss Dyck                                                NaN
# 10720  Schloss Dyck                                                NaN
# 10721  Schloss Dyck                                                NaN
# 10722  Schloss Dyck                                                NaN
#
#                       Digitalisate: Dateiname (Signatur)  \
# 2892   CdS-b1-08jg-0.jpg (CdS/31/166); CdS-b1-08jg-1....
# 3378   CdS-b1-08je-0.jpg (CdS/31/132); CdS-b1-08je-1....
# 4327   CdS-b1-08jf-0.jpg (CdS/31/158); CdS-b1-08jf-1....
# 5439                      CdS-b1-07r3-0.jpg (CdS/28/003)
# 5467   CdS-b1-07vy-0.jpg (CdS/16/003); CdS-b1-07vy-1....
# ...                                                  ...
# 10718  CdS-b1-08jb-0.jpg (CdS/31/098); CdS-b1-08jb-1....
# 10719  CdS-b1-08iz-0.jpg (CdS/31/062); CdS-b1-08iz-1....
# 10720  CdS-b1-08in-0.jpg (CdS/31/039); CdS-b1-08in-1....
# 10721  CdS-b1-08j6-0.jpg (CdS/31/079); CdS-b1-08j6-1....
# 10722                      CdS-b1-08ib-0.jpg (CdS/31/21)
#
#                                         Zitierempfehlung
# 2892   CdS/31/166-167. In: Die Korrespondenz der Cons...
# 3378   CdS/31/132-135. In: Die Korrespondenz der Cons...
# 4327   CdS/31/158-160. In: Die Korrespondenz der Cons...
# 5439   CdS/28/003. In: Die Korrespondenz der Constanc...
# 5467   CdS/16/003-004. In: Die Korrespondenz der Cons...
# ...                                                  ...
# 10718  CdS/31/098-099. In: Die Korrespondenz der Cons...
# 10719  CdS/31/062-063. In: Die Korrespondenz der Cons...
# 10720  CdS/31/039-040. In: Die Korrespondenz der Cons...
# 10721  CdS/31/079-080. In: Die Korrespondenz der Cons...
# 10722  CdS/31/21. In: Die Korrespondenz der Constance...
#
# [389 rows x 35 columns]

# %% [markdown]
# Exporting the extracted meta-Informations in "Donnes_Lettres"

# %%
# !pip install openpyxl
df_part.to_csv('Donnees_Lettres/Constance_de_Salm_Special_lettres.csv', encoding='utf8', sep=';')
df_part.to_excel('Donnees_Lettres/Constance_de_Salm_Special_lettres.xlsx', encoding='utf8')

df_part
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 4.3 MB/s
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
#            FuD-Key   letzte Änderung Dokumenttyp  \
# 2892   CdS-b1-08jg  26.08.2021 10:44       Brief
# 3378   CdS-b1-08je  26.08.2021 10:44       Brief
# 4327   CdS-b1-08jf  26.08.2021 10:44       Brief
# 5439   CdS-b1-07r3  26.08.2021 10:44       Brief
# 5467   CdS-b1-07vy  26.08.2021 10:44       Brief
# ...            ...               ...         ...
# 10718  CdS-b1-08jb  26.08.2021 10:44       Brief
# 10719  CdS-b1-08iz  26.08.2021 10:44       Brief
# 10720  CdS-b1-08in  26.08.2021 10:44       Brief
# 10721  CdS-b1-08j6  26.08.2021 10:44       Brief
# 10722  CdS-b1-08ib  26.08.2021 10:44       Brief
#
#                                                      URL             Nr.  \
# 2892   https://constance-de-salm.de/archiv/#/document...  CdS/31/166-167
# 3378   https://constance-de-salm.de/archiv/#/document...  CdS/31/132-135
# 4327   https://constance-de-salm.de/archiv/#/document...  CdS/31/158-160
# 5439   https://constance-de-salm.de/archiv/#/document...      CdS/28/003
# 5467   https://constance-de-salm.de/archiv/#/document...  CdS/16/003-004
# ...                                                  ...             ...
# 10718  https://constance-de-salm.de/archiv/#/document...  CdS/31/098-099
# 10719  https://constance-de-salm.de/archiv/#/document...  CdS/31/062-063
# 10720  https://constance-de-salm.de/archiv/#/document...  CdS/31/039-040
# 10721  https://constance-de-salm.de/archiv/#/document...  CdS/31/079-080
# 10722  https://constance-de-salm.de/archiv/#/document...       CdS/31/21
#
#                       Verfasser                 GND (Verfasser)  \
# 2892   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 3378   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 4327   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 5439   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 5467   Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# ...                         ...                             ...
# 10718  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10719  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10720  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10721  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
# 10722  Salm, Constance de (CdS)  http://d-nb.info/gnd/116765968
#
#                    VIAF (Verfasser)  \
# 2892   https://viaf.org/viaf/121051
# 3378   https://viaf.org/viaf/121051
# 4327   https://viaf.org/viaf/121051
# 5439   https://viaf.org/viaf/121051
# 5467   https://viaf.org/viaf/121051
# ...                             ...
# 10718  https://viaf.org/viaf/121051
# 10719  https://viaf.org/viaf/121051
# 10720  https://viaf.org/viaf/121051
# 10721  https://viaf.org/viaf/121051
# 10722  https://viaf.org/viaf/121051
#
#                                                Empfänger  \
# 2892   Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 3378   Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 4327   Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 5439   Duval, Alexandre, eigentl. Alexandre-Vincent P...
# 5467   Théis, Alexandre Étienne Guillaume, baron de (...
# ...                                                  ...
# 10718  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10719  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10720  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10721  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
# 10722  Pailliet, Jean Baptiste Joseph (Anwalt der CdS...
#
#                       GND (Empfänger)  ...  \
# 2892   http://d-nb.info/gnd/121286169  ...
# 3378   http://d-nb.info/gnd/121286169  ...
# 4327   http://d-nb.info/gnd/121286169  ...
# 5439   http://d-nb.info/gnd/104201088  ...
# 5467   http://d-nb.info/gnd/120564734  ...
# ...                               ...  ...
# 10718  http://d-nb.info/gnd/121286169  ...
# 10719  http://d-nb.info/gnd/121286169  ...
# 10720  http://d-nb.info/gnd/121286169  ...
# 10721  http://d-nb.info/gnd/121286169  ...
# 10722  http://d-nb.info/gnd/121286169  ...
#
#                                  VIAF (Weitere Personen)            Orte  \
# 2892                     https://viaf.org/viaf/188712285             NaN
# 3378   http://viaf.org/viaf/32148970; n/a; http://via...           Tours
# 4327         http://viaf.org/viaf/1847152636116120051820             NaN
# 5439                       http://viaf.org/viaf/59072566          Aachen
# 5467         http://viaf.org/viaf/1847152636116120051820             NaN
# ...                                                  ...             ...
# 10718                 http://viaf.org/viaf/54933372; n/a           Tours
# 10719          https://viaf.org/viaf/188712285; n/a; n/a             NaN
# 10720                                           n/a; n/a    Tours; Coucy
# 10721                                      n/a; n/a; n/a  Orléans; Coucy
# 10722                                                NaN             NaN
#
#                                          Geonames (Orte)  \
# 2892                                                 NaN
# 3378                    https://www.geonames.org/2972191
# 4327                                                 NaN
# 5439                    https://www.geonames.org/3247449
# 5467                                                 NaN
# ...                                                  ...
# 10718                   https://www.geonames.org/2972191
# 10719                                                NaN
# 10720  https://www.geonames.org/2972191; https://www....
# 10721  https://www.geonames.org/2989317; https://www....
# 10722                                                NaN
#
#                                             Schlagwörter Editionen  Vermerk  \
# 2892   CdS: Œuvres complètes (1842); Tod/Trauer; CdS:...       NaN      NaN
# 3378                Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 4327                Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 5439                           Deutschland - Wahrnehmung       NaN      NaN
# 5467                                          Verbrechen       NaN      NaN
# ...                                                  ...       ...      ...
# 10718                                    Prozess/Gericht       NaN      NaN
# 10719               Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 10720                                    Prozess/Gericht       NaN      NaN
# 10721               Wirtschaft/Finanzen; Prozess/Gericht       NaN      NaN
# 10722                                    Prozess/Gericht       NaN      NaN
#
#             Bestand                                           Verweise  \
# 2892   Schloss Dyck                                                NaN
# 3378   Schloss Dyck                                                NaN
# 4327   Schloss Dyck                                                NaN
# 5439   Schloss Dyck  (https://constance-de-salm.de/archiv/#/documen...
# 5467   Schloss Dyck                                                NaN
# ...             ...                                                ...
# 10718  Schloss Dyck                                                NaN
# 10719  Schloss Dyck                                                NaN
# 10720  Schloss Dyck                                                NaN
# 10721  Schloss Dyck                                                NaN
# 10722  Schloss Dyck                                                NaN
#
#                       Digitalisate: Dateiname (Signatur)  \
# 2892   CdS-b1-08jg-0.jpg (CdS/31/166); CdS-b1-08jg-1....
# 3378   CdS-b1-08je-0.jpg (CdS/31/132); CdS-b1-08je-1....
# 4327   CdS-b1-08jf-0.jpg (CdS/31/158); CdS-b1-08jf-1....
# 5439                      CdS-b1-07r3-0.jpg (CdS/28/003)
# 5467   CdS-b1-07vy-0.jpg (CdS/16/003); CdS-b1-07vy-1....
# ...                                                  ...
# 10718  CdS-b1-08jb-0.jpg (CdS/31/098); CdS-b1-08jb-1....
# 10719  CdS-b1-08iz-0.jpg (CdS/31/062); CdS-b1-08iz-1....
# 10720  CdS-b1-08in-0.jpg (CdS/31/039); CdS-b1-08in-1....
# 10721  CdS-b1-08j6-0.jpg (CdS/31/079); CdS-b1-08j6-1....
# 10722                      CdS-b1-08ib-0.jpg (CdS/31/21)
#
#                                         Zitierempfehlung
# 2892   CdS/31/166-167. In: Die Korrespondenz der Cons...
# 3378   CdS/31/132-135. In: Die Korrespondenz der Cons...
# 4327   CdS/31/158-160. In: Die Korrespondenz der Cons...
# 5439   CdS/28/003. In: Die Korrespondenz der Constanc...
# 5467   CdS/16/003-004. In: Die Korrespondenz der Cons...
# ...                                                  ...
# 10718  CdS/31/098-099. In: Die Korrespondenz der Cons...
# 10719  CdS/31/062-063. In: Die Korrespondenz der Cons...
# 10720  CdS/31/039-040. In: Die Korrespondenz der Cons...
# 10721  CdS/31/079-080. In: Die Korrespondenz der Cons...
# 10722  CdS/31/21. In: Die Korrespondenz der Constance...
#
# [389 rows x 35 columns]

# %% [markdown]
# Visualizing the "Schlagwörter" of the special df.

# %%
#!pip install wordcloud
import wordcloud as wc

def create_wordcloud(text):
    if type(text) is pd.Series:
        text: pd.Series
        tmp = ''
        for i, v in text.iteritems():
            try:
                for j in v.split('; '):
                    tmp += j + ' '
            except AttributeError:
                continue
        text = tmp
    cloud = wc.WordCloud(width=800, height=400, background_color="white")
    cl = cloud.generate_from_text(text)
    return cl.to_image()
create_wordcloud(df_part['Schlagwörter'])
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F14EB5390A0>

# %%
create_wordcloud(df['Schlagwörter'])
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F14EB536AC0>
